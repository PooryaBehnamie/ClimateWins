# %% [markdown]
# ## This script includes the following points:
# 1. Importing libraries
# 2. Change the default setting of jupyter notebook
# 3. Finding Mixed-Type Data in any column
# 4. Missing Values
# 5. Duplicates
# 5. Combine two DataFrames

# %% [markdown]
# ### 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
# Making the project folder a path
path = r"C:\Users\Poory\OneDrive\Desktop\project\ClimateWins"

# %%
# Import Data Set
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Dataset-weather-prediction-dataset-processed.csv'))
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
# change Jupyter Notebook default setting
pd.set_option('display.max_column', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB

# %%
df.describe()
# Out:
#                DATE         MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# count  2.295000e+04  22950.000000       22950.000000      22950.000000
# mean   1.990984e+07      6.509630           5.410763          2.120462
# std    1.813833e+05      3.443672           2.406115          0.732625
# min    1.960010e+07      1.000000           0.000000          0.000000
# 25%    1.975092e+07      4.000000           4.000000          2.100000
# 50%    1.991060e+07      7.000000           6.000000          2.100000
# 75%    2.007021e+07      9.000000           7.000000          2.100000
# max    2.022103e+07     12.000000           8.000000         16.300000
#
#        BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# count    22950.000000    22950.000000            22950.000000
# mean         0.758554        1.018013                1.345244
# std          0.110699        0.006543                0.931158
# min          0.350000        0.974700                0.010000
# ...

# %%
# Check for missing values
pd.set_option('display.max_rows', 170)
df.isnull().sum()
# Out:
# DATE                           0
# MONTH                          0
# BASEL_cloud_cover              0
# BASEL_wind_speed               0
# BASEL_humidity                 0
# BASEL_pressure                 0
# BASEL_global_radiation         0
# BASEL_precipitation            0
# BASEL_snow_depth               0
# BASEL_sunshine                 0
# BASEL_temp_mean                0
# BASEL_temp_min                 0
# BASEL_temp_max                 0
# BELGRADE_cloud_cover           0
# BELGRADE_humidity              0
# BELGRADE_pressure              0
# BELGRADE_global_radiation      0
# BELGRADE_precipitation         0
# BELGRADE_sunshine              0
# BELGRADE_temp_mean             0
# BELGRADE_temp_min              0
# BELGRADE_temp_max              0
# BUDAPEST_cloud_cover           0
# BUDAPEST_humidity              0
# BUDAPEST_pressure              0
# BUDAPEST_global_radiation      0
# BUDAPEST_precipitation         0
# BUDAPEST_sunshine              0
# ...

# %%
df.dtypes
# Out:
# DATE                             int64
# MONTH                            int64
# BASEL_cloud_cover                int64
# BASEL_wind_speed               float64
# BASEL_humidity                 float64
# BASEL_pressure                 float64
# BASEL_global_radiation         float64
# BASEL_precipitation            float64
# BASEL_snow_depth                 int64
# BASEL_sunshine                 float64
# BASEL_temp_mean                float64
# BASEL_temp_min                 float64
# BASEL_temp_max                 float64
# BELGRADE_cloud_cover             int64
# BELGRADE_humidity              float64
# BELGRADE_pressure              float64
# BELGRADE_global_radiation      float64
# BELGRADE_precipitation         float64
# BELGRADE_sunshine              float64
# BELGRADE_temp_mean             float64
# BELGRADE_temp_min              float64
# BELGRADE_temp_max              float64
# BUDAPEST_cloud_cover             int64
# BUDAPEST_humidity              float64
# ...

# %%
df.shape
# Out:
# (22950, 170)

# %%
# Check for duplicats
df_dup = df.loc[df.duplicated()]
df_dup
# Out:
# Empty DataFrame
# ...

# %%
# Check for columns with inconsistent data types in specific columns (chatGPT version)
for col in df.columns.tolist():
    
    # Check if there are any inconsistencies in data types within the column
    weird = (df[[col]].apply(lambda x: x.map(type)) != df[[col]].iloc[0].apply(type)).any(axis=1)
    
    # If inconsistencies are found, print the column name
    if len(df[weird]) > 0:
        print(col)
    else:
        print(f'There is no mixed-type data in {col}')
# Out:
# There is no mixed-type data in DATE
# There is no mixed-type data in MONTH
# There is no mixed-type data in BASEL_cloud_cover
# There is no mixed-type data in BASEL_wind_speed
# There is no mixed-type data in BASEL_humidity
# There is no mixed-type data in BASEL_pressure
# There is no mixed-type data in BASEL_global_radiation
# There is no mixed-type data in BASEL_precipitation
# There is no mixed-type data in BASEL_snow_depth
# There is no mixed-type data in BASEL_sunshine
# There is no mixed-type data in BASEL_temp_mean
# There is no mixed-type data in BASEL_temp_min
# There is no mixed-type data in BASEL_temp_max
# There is no mixed-type data in BELGRADE_cloud_cover
# There is no mixed-type data in BELGRADE_humidity
# There is no mixed-type data in BELGRADE_pressure
# There is no mixed-type data in BELGRADE_global_radiation
# There is no mixed-type data in BELGRADE_precipitation
# There is no mixed-type data in BELGRADE_sunshine
# There is no mixed-type data in BELGRADE_temp_mean
# ...

# %% [markdown]
# ### 2. Scaling

# %%
#create a scaler object using StandardScaler from sklearn.preprocessing
#StandardScaler assumes data is normally distributed and scales with a distribution
#around 0 and a standard deviation of 1. Scaling happens independently with each variable.

scaler = StandardScaler()

# %%
#create new df with scaled data

df_scaled = pd.DataFrame(scaler.fit_transform(df))
df_scaled.head()
# Out:
#         0         1         2        3         4         5         6    \
# 0 -1.707663 -1.599964  0.660514 -0.02793  0.826097 -0.001949 -1.101066
# 1 -1.707657 -1.599964  0.244897 -0.02793  0.735760 -0.001949 -1.058108
# 2 -1.707652 -1.599964  1.076130 -0.02793  1.277781 -0.001949 -1.251420
# 3 -1.707646 -1.599964 -1.001953 -0.02793  1.458455 -0.001949 -0.821838
# 4 -1.707641 -1.599964  0.244897 -0.02793  1.729466 -0.001949 -0.746661
#
#         7         8         9         10        11        12        13   \
# 0 -0.265148 -0.179228 -0.902918 -0.528623 -0.845652 -0.478356 -1.206433
# 1  1.658760 -0.179228 -0.810126 -0.582946 -0.462450 -0.569988  0.652846
# 2  0.155707 -0.179228 -1.065304 -0.257010 -0.186545 -0.592896  0.652846
# 3 -0.445514 -0.179228 -0.114186 -0.555784 -0.385810 -0.512718  1.396557
# 4 -0.164944 -0.179228  0.187388 -1.003946 -1.075573 -1.039603  1.396557
#
#         14        15        16        17        18        19        20   \
# ...

# %%
df_scaled.columns = df.columns
df_scaled.head(10)
# Out:
#        DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0 -1.707663 -1.599964           0.660514          -0.02793        0.826097
# 1 -1.707657 -1.599964           0.244897          -0.02793        0.735760
# 2 -1.707652 -1.599964           1.076130          -0.02793        1.277781
# 3 -1.707646 -1.599964          -1.001953          -0.02793        1.458455
# 4 -1.707641 -1.599964           0.244897          -0.02793        1.729466
# 5 -1.707635 -1.599964          -1.833187          -0.02793        0.193738
# 6 -1.707630 -1.599964          -1.001953          -0.02793        1.006770
# 7 -1.707624 -1.599964           1.076130          -0.02793        1.729466
# 8 -1.707619 -1.599964           1.076130          -0.02793        2.000476
# 9 -1.707613 -1.599964          -1.001953          -0.02793       -0.167609
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# ...

# %%
# Save Scaled Data Set

df_scaled.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Weather_Dataset_scaled.pkl'))
